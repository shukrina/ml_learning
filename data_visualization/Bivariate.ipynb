# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('../diabetes_dataset/diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# 1. Scatterplot (Numerical - numerical)

# %%
# sns.scatterplot(x=df['Age'], y=df['Glucose']) 
sns.scatterplot(x=df['Age'], y=df['Glucose'], hue=df['Outcome'])
# Out:
# <Axes: xlabel='Age', ylabel='Glucose'>

# %% [markdown]
# 2. Bar Plot (Numerical - Categorical)

# %%
sns.barplot(x=df['Outcome'], y=df['Glucose'])
# Out:
# <Axes: xlabel='Outcome', ylabel='Glucose'>

# %%
sns.barplot(x=df['Outcome'], y=df['Age'], hue=df['Pregnancies'])
# Out:
# <Axes: xlabel='Outcome', ylabel='Age'>

# %% [markdown]
# 3. BoxPlot (Numerical - Categorical)

# %%
sns.boxplot(x=df['Outcome'], y=df['Age']) #another categorical column could be kept as hue=df['col_name'] but there are no other categorical columns except outcome
# Out:
# <Axes: xlabel='Outcome', ylabel='Age'>

# %% [markdown]
# 4. Distplot(Numerical - Categorical)

# %%
sns.displot(x =df['Age'],kde=True,stat='density',linewidth=0)
# Out:
# /home/shukrina/Documents/vertex/vertex_projects/diabetes_detection/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(df[df['Outcome']==0]['Age'],kde=True, stat="density", linewidth=0)
# Out:
# /home/shukrina/Documents/vertex/vertex_projects/diabetes_detection/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.histplot(df[df['Outcome']==0]['Age'],kde=True, stat="density", linewidth=0, fill=False)
sns.histplot(df[df['Outcome']==1]['Age'],kde=True, stat="density", linewidth=0, fill=False)
# Out:
# /home/shukrina/Documents/vertex/vertex_projects/diabetes_detection/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/shukrina/Documents/vertex/vertex_projects/diabetes_detection/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# 5. HeatMap (Categorical - Categorical)

# %%
#Since there is only one categorical column, this is not possible
#pd.crosstab(df['Outcome'], df['Other_categorical_column'])

# %%
#sns.heatmap(pd.crosstab(df['Outcome'], df['Other_categorical_column']))

# %% [markdown]
# 6. ClusterMap (Categorical - Categorical)

# %%
#Since there is only one categorical column, this is not possible
#pd.crosstab(df['Outcome'], df['Other_categorical_column'])
#sns.clustermap(pd.crosstab(df['Outcome'], df['Other_categorical_column']))

# %% [markdown]
# 7. Pairplot

# %%
sns.pairplot(df)
# Out:
# /home/shukrina/Documents/vertex/vertex_projects/diabetes_detection/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/shukrina/Documents/vertex/vertex_projects/diabetes_detection/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/shukrina/Documents/vertex/vertex_projects/diabetes_detection/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.pairplot(df, hue='Outcome')
# Out:
# /home/shukrina/Documents/vertex/vertex_projects/diabetes_detection/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/shukrina/Documents/vertex/vertex_projects/diabetes_detection/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# 8. Lineplot (Numerical - Numerical)

# %%
sns.lineplot(x=df['Age'], y=df['BloodPressure'])
# Out:
# /home/shukrina/Documents/vertex/vertex_projects/diabetes_detection/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/shukrina/Documents/vertex/vertex_projects/diabetes_detection/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
