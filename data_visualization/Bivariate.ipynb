# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('../diabetes_dataset/diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# 1. Scatterplot (Numerical - numerical)

# %%
# sns.scatterplot(x=df['Age'], y=df['Glucose']) 
sns.scatterplot(x=df['Age'], y=df['Glucose'], hue=df['Outcome'])
# Out:
# <Axes: xlabel='Age', ylabel='Glucose'>

# %% [markdown]
# 2. Bar Plot (Numerical - Categorical)

# %%
sns.barplot(x=df['Pregnancies'], y=df['Glucose'])
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Glucose'>

# %%
sns.barplot(x=df['Pregnancies'], y=df['Glucose'], hue=df['Outcome'])
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Glucose'>
