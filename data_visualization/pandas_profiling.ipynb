# %%
import pandas as pd

# %%
df=pd.read_csv('../diabetes_dataset/diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# !pip install pandas-profiling
# !pip uninstall pandas-profiling -y
# !uv remove seaborn numpy ydata-profiling
# !uv add "numpy==2.3.3" "seaborn<0.13"
# Out:
# m⠙ rfc3986-validator==0.1.1                                                      Resolved 114 packages in 79ms
# Uninstalled 28 packages in 240ms
#  - contourpy==1.3.3
#  - cycler==0.12.1
#  - dacite==1.9.2
#  - filetype==1.2.0
#  - fonttools==4.61.1
#  - imagehash==4.3.2
#  - joblib==1.5.3
#  - kiwisolver==1.4.9
#  - llvmlite==0.45.1
#  - matplotlib==3.10.0
#  - minify-html==0.18.1
#  - multimethod==1.12
#  - networkx==3.6.1
#  - numba==0.62.1
#  - patsy==1.0.2
#  - phik==0.12.5
#  - pillow==12.1.0
#  - puremagic==1.30
#  - pyparsing==3.3.2
#  - pywavelets==1.9.0
#  - scipy==1.16.3
#  - seaborn==0.12.2
#  - statsmodels==0.14.6
#  - tqdm==4.67.2
#  - typeguard==4.4.4
#  - visions==0.8.1
#  - wordcloud==1.9.6
#  - ydata-profiling==4.18.1
# Resolved 122 packages in 118ms
# Installed 8 packages in 30ms
#  + contourpy==1.3.3
#  + cycler==0.12.1
#  + fonttools==4.61.1
#  + kiwisolver==1.4.9
#  + matplotlib==3.10.8
#  + pillow==12.1.0
#  + pyparsing==3.3.2
#  + seaborn==0.12.2

# %%
# !uv add ydata-profiling
# Out:
# Resolved 142 packages in 130ms
# Uninstalled 1 package in 10ms
# Installed 21 packages in 58ms
#  + dacite==1.9.2
#  + filetype==1.2.0
#  + imagehash==4.3.2
#  + joblib==1.5.3
#  + llvmlite==0.45.1
#  - matplotlib==3.10.8
#  + matplotlib==3.10.0
#  + minify-html==0.18.1
#  + multimethod==1.12
#  + networkx==3.6.1
#  + numba==0.62.1
#  + patsy==1.0.2
#  + phik==0.12.5
#  + puremagic==1.30
#  + pywavelets==1.9.0
#  + scipy==1.16.3
#  + statsmodels==0.14.6
#  + tqdm==4.67.2
#  + typeguard==4.4.4
#  + visions==0.8.1
#  + wordcloud==1.9.6
#  + ydata-profiling==4.18.1

# %%
# !uv pip list
# !uv pip show numba
# Out:
# Using Python 3.11.14 environment at: /home/shukrina/Documents/vertex/vertex_projects/diabetes_detection/.venv
# Name: numba
# Version: 0.62.1
# Location: /home/shukrina/Documents/vertex/vertex_projects/diabetes_detection/.venv/lib/python3.11/site-packages
# Requires: llvmlite, numpy
# Required-by: ydata-profiling

# %%
# !uv pip show numpy numba ydata-profiling
# Out:
# Using Python 3.11.14 environment at: /home/shukrina/Documents/vertex/vertex_projects/diabetes_detection/.venv
# Name: numba
# Version: 0.62.1
# Location: /home/shukrina/Documents/vertex/vertex_projects/diabetes_detection/.venv/lib/python3.11/site-packages
# Requires: llvmlite, numpy
# Required-by: ydata-profiling
# ---
# Name: numpy
# Version: 2.3.3
# Location: /home/shukrina/Documents/vertex/vertex_projects/diabetes_detection/.venv/lib/python3.11/site-packages
# Requires:
# Required-by: contourpy, imagehash, matplotlib, numba, pandas, patsy, phik, pywavelets, scipy, seaborn, statsmodels, visions, wordcloud, ydata-profiling
# ---
# Name: ydata-profiling
# Version: 4.18.1
# Location: /home/shukrina/Documents/vertex/vertex_projects/diabetes_detection/.venv/lib/python3.11/site-packages
# ...

# %%
from ydata_profiling import ProfileReport

prof = ProfileReport(df, explorative=True)
prof.to_file("output.html")

# from pandas_profiling import ProfileReport 
# prof = ProfileReport(df) 
# prof.to_file(output_file='output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
